# %% [markdown]
# #**Notas de Probabilidad y Estadística - Semana 1 🐢**
# #####¡Hola el que esté leyendo esto! No se como empezar esto, solo son notas mias de esta materia que corresponde la primer semana de la misma. pondré una imagen como portada para que se vea presentable.
# ![Tf2 Soldier Team Fortress Wallpaper High Quality (1).jpg](data:image/jpeg;base64,...)
# ---
# Conceptos:
# 1. Estadística
# 2. Probabilidad
# 3. Dato
# 4. Evento
# 5. Axiomas
#
#
# - Probabilidad: Es una rama de las matemáticas que mide la posibilidad de que ocurra un evento. Su valor se encuentra entre 0 (imposible) y 1 (seguro).
#
# - Estadística: Es la disciplina que recopila, organiza, analiza e interpreta datos para tomar decisiones informadas o entender fenómenos.
#
# - Dato: Es una unidad básica de información, que puede ser cuantitativa (números) o cualitativa (categorías), utilizada para análisis o toma de decisiones.
#
# - Evento: En probabilidad, es el conjunto de resultados posibles asociados a un experimento. Por ejemplo, obtener cara al lanzar una moneda.
#
# - Axiomas: Son principios fundamentales aceptados sin necesidad de demostración que sirven de base para desarrollar teorías, como los axiomas de probabilidad de Kolmogórov.
#
#
# ###**Estadística Descriptiva:** Se encarga de recopilar, organizar, resumir y presentar datos mediante gráficos, tablas y medidas estadísticas (como la media, mediana, moda o desviación estándar) para describir las características principales de un conjunto de datos.
#
# ###**Estadística Inferencial:** Utiliza una muestra de datos para hacer generalizaciones, predicciones o tomar decisiones sobre una población completa. Emplea técnicas como estimación de parámetros, pruebas de hipótesis y análisis de regresión.
#
# ---
# Si alguien ve esto ajeno al profesor puede basar mi info que tengo, no calcarlo. Sino, habrá tabla.
#
# ![images.png](data:image/png;base64,...)
